# %% [markdown]
# # DRIVING TO SUCCESS

# %% [markdown]
# ## Import Dependancies

# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import requests
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from sqlalchemy import create_engine

# %% [markdown]
# ## CSV Import and Process Data

# %%
#Import the CSV from the Resources folder

file_path = "Resources/vehicles.csv"
cars_df = pd.read_csv(file_path)
cars_df.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# 0          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 1          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 2          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 3          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 4          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
#
#   image_url description county state lat long posting_date
# 0       NaN         NaN    NaN    az NaN  NaN          NaN
# 1       NaN         NaN    NaN    ar NaN  NaN          NaN
# 2       NaN         NaN    NaN    fl NaN  NaN          NaN
# 3       NaN         NaN    NaN    ma NaN  NaN          NaN
# 4       NaN         NaN    NaN    nc NaN  NaN          NaN
#
# [5 rows x 26 columns]

# %%
#Check the existing columns
cars_df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
#Drop unwanted columns
new_cars_df = cars_df[["price", "year", "manufacturer", "model", "odometer", "fuel", "transmission"]]
new_cars_df
# Out:
#         price    year manufacturer                     model  odometer  \
# 0        6000     NaN          NaN                       NaN       NaN
# 1       11900     NaN          NaN                       NaN       NaN
# 2       21000     NaN          NaN                       NaN       NaN
# 3        1500     NaN          NaN                       NaN       NaN
# 4        4900     NaN          NaN                       NaN       NaN
# ...       ...     ...          ...                       ...       ...
# 426875  23590  2019.0       nissan         maxima s sedan 4d   32226.0
# 426876  30590  2020.0        volvo  s60 t5 momentum sedan 4d   12029.0
# 426877  34990  2020.0     cadillac          xt4 sport suv 4d    4174.0
# 426878  28990  2018.0        lexus           es 350 sedan 4d   30112.0
# 426879  30590  2019.0          bmw  4 series 430i gran coupe   22716.0
#
#           fuel transmission
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# ...        ...          ...
# 426875     gas        other
# 426876     gas        other
# 426877  diesel        other
# 426878     gas        other
# 426879     gas        other
#
# [426880 rows x 7 columns]

# %%
new_cars_df = new_cars_df.dropna(how ='any')
new_cars_df
# Out:
#         price    year manufacturer                     model  odometer  \
# 27      33590  2014.0          gmc  sierra 1500 crew cab slt   57923.0
# 28      22590  2010.0    chevrolet            silverado 1500   71229.0
# 29      39590  2020.0    chevrolet       silverado 1500 crew   19160.0
# 30      30990  2017.0       toyota      tundra double cab sr   41124.0
# 31      15000  2013.0         ford                 f-150 xlt  128000.0
# ...       ...     ...          ...                       ...       ...
# 426875  23590  2019.0       nissan         maxima s sedan 4d   32226.0
# 426876  30590  2020.0        volvo  s60 t5 momentum sedan 4d   12029.0
# 426877  34990  2020.0     cadillac          xt4 sport suv 4d    4174.0
# 426878  28990  2018.0        lexus           es 350 sedan 4d   30112.0
# 426879  30590  2019.0          bmw  4 series 430i gran coupe   22716.0
#
#           fuel transmission
# 27         gas        other
# 28         gas        other
# 29         gas        other
# 30         gas        other
# 31         gas    automatic
# ...        ...          ...
# 426875     gas        other
# 426876     gas        other
# 426877  diesel        other
# 426878     gas        other
# 426879     gas        other
#
# [396334 rows x 7 columns]

# %%
new_cars_df = new_cars_df.reset_index(drop = True)
new_cars_df
# Out:
#         price    year manufacturer                     model  odometer  \
# 0       33590  2014.0          gmc  sierra 1500 crew cab slt   57923.0
# 1       22590  2010.0    chevrolet            silverado 1500   71229.0
# 2       39590  2020.0    chevrolet       silverado 1500 crew   19160.0
# 3       30990  2017.0       toyota      tundra double cab sr   41124.0
# 4       15000  2013.0         ford                 f-150 xlt  128000.0
# ...       ...     ...          ...                       ...       ...
# 396329  23590  2019.0       nissan         maxima s sedan 4d   32226.0
# 396330  30590  2020.0        volvo  s60 t5 momentum sedan 4d   12029.0
# 396331  34990  2020.0     cadillac          xt4 sport suv 4d    4174.0
# 396332  28990  2018.0        lexus           es 350 sedan 4d   30112.0
# 396333  30590  2019.0          bmw  4 series 430i gran coupe   22716.0
#
#           fuel transmission
# 0          gas        other
# 1          gas        other
# 2          gas        other
# 3          gas        other
# 4          gas    automatic
# ...        ...          ...
# 396329     gas        other
# 396330     gas        other
# 396331  diesel        other
# 396332     gas        other
# 396333     gas        other
#
# [396334 rows x 7 columns]

# %%
new_cars_df = new_cars_df.rename(columns = {'odometer': 'mileage'}
                                )
new_cars_df
# Out:
#         price    year manufacturer                     model   mileage  \
# 0       33590  2014.0          gmc  sierra 1500 crew cab slt   57923.0
# 1       22590  2010.0    chevrolet            silverado 1500   71229.0
# 2       39590  2020.0    chevrolet       silverado 1500 crew   19160.0
# 3       30990  2017.0       toyota      tundra double cab sr   41124.0
# 4       15000  2013.0         ford                 f-150 xlt  128000.0
# ...       ...     ...          ...                       ...       ...
# 396329  23590  2019.0       nissan         maxima s sedan 4d   32226.0
# 396330  30590  2020.0        volvo  s60 t5 momentum sedan 4d   12029.0
# 396331  34990  2020.0     cadillac          xt4 sport suv 4d    4174.0
# 396332  28990  2018.0        lexus           es 350 sedan 4d   30112.0
# 396333  30590  2019.0          bmw  4 series 430i gran coupe   22716.0
#
#           fuel transmission
# 0          gas        other
# 1          gas        other
# 2          gas        other
# 3          gas        other
# 4          gas    automatic
# ...        ...          ...
# 396329     gas        other
# 396330     gas        other
# 396331  diesel        other
# 396332     gas        other
# 396333     gas        other
#
# [396334 rows x 7 columns]

# %% [markdown]
# # Web-Scraping

# %%
#Now we try to do the static web-scrape, it used to work and produce a DataFrame of 12 cars, but it doesnt now for some reason
#It says Access Denied now, proper gutted, smh.

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

url = 'https://www.autotrader.co.uk/car-search?postcode=G72%208JD&year-to=2022&include-delivery-option=on&advertising-location=at_cars&page=1'
#response = requests.get(url)
browser.visit(url) 
#print(response)

html = browser.html
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <html class="sp-message-open" data-feature="new-buttons" style="top: 0px;">
#  <head>
#   <meta content="/323304435/web/cars/search/listings" name="gpt1"/>
#   <meta content="/323304435/web/cars/content/sponsored" name="gpt2"/>
#   <script async="" src="https://m.atcdn.co.uk/frostbite/2.18.1/e0e2dedc5afbf82139142689c494c4b3.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#   </script>
#   <meta content="follow,noindex" name="robots"/>
#   <meta content="blank" name="decorator"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
#    /*inline-script*/
#     var isiPad = navigator.userAgent.match(/iPad/i) != null;
#     if(isiPad) document.write('<meta name="viewport" content="user-scalable=yes, width=device-width"/>');
#
#     window.isCarsOrVans = true
#   </script>
#   <title>
#    New &amp; Used Cars for Sale - Auto Trader UK
#   </title>
#   <link href="/images/favicons/favicon.png" rel="icon"/>
#   <link href="/images/favicons/touch-icon-iphone.png" rel="apple-touch-icon"/>
#   <link href="/images/favicons/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/images/favicons/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/images/favicons/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="AutoTrader" name="application-name"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="/images/favicons/msapplication-tiny.png" name="msapplication-square70x70logo"/>
#   <meta content="/images/favicons/msapplication-square.png" name="msapplication-square150x150logo"/>
#   <meta content="/images/favicons/msapplication-wide.png" name="msapplication-wide310x150logo"/>
#   <meta content="/images/favicons/msapplication-large.png" name="msapplication-square310x310logo"/>
#   <link href="https://www.autotrader.co.uk:443/static/9690/css/_generated/page-sets/search.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/css/_generated/page-sets/font-fabriga-beta.css" rel="stylesheet"/>
#   <link href="https://www.autotrader.co.uk:443/static/9690/css/_generated/page-sets/foundation.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script>
#    window.abTestGroups="hpI-segI-chI-mrI-boT-vcT-cp0I-iooC-biT-ipT-fdpT-anonF-meI-slI-anA-rgI-vtT-evcI-ctI-evI-rcI-drI-tpcT"
#   </script>
#   <script>
#    window.abTCId="74342266_73c1_4156_bb9f_55cde114e7b8"
#   </script>
#   <!--start Sourcepoint code-->
#   <script type="text/javascript">
#    !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
#   </script>
#   <script>
#    var getCookie = function (name) {
#     var value = '; ' + document.cookie
#     var parts = value.split('; ' + name + '=')
#     if (parts.length >= 2) return parts.pop().split(';').shift()
#   };
#
#   var setCookie = function (cName, cValue, expMinutes) {
#     deleteCookie(cName);
#     let date = new Date();
#     date.setTime(date.getTime() + (expMinutes * 60 * 1000));
#     const expires = "expires=" + date.toUTCString();
#     document.cookie = cName + "=" + cValue + "; " + expires + "; domain=.autotrader.co.uk; path=/";
#   };
#
#   var readAbTestGroupsCookie = function () {
#     return getCookie('abTestGroups') || ''
#   };
#
#   var isConsentTrackingShielded = function () {
#     var cookieString = readAbTestGroupsCookie();
#     return cookieString && cookieString.includes('anonA')
#   };
#
#   var deleteCookie = function (cName) {
#     const value = ('; ' + document.cookie).split(`; COOKIE_NAME=`).pop().split(';')[0];
#     document.cookie = cName + '=; domain=.autotrader.co.uk; Max-Age=-99999999;';
#     document.cookie = cName + '=; domain=www.autotrader.co.uk; Max-Age=-99999999;';
#   };
#
#   var daysToMinutes = function (days) {
#     return days * 24 * 60
#   };
#
#   var onApproveAutoTraderCookies = function () {
#     setCookie('acceptATCookies', 'true', daysToMinutes(365));
#     if (window.abTestGroups) {
#       setCookie('abTestGroups', window.abTestGroups, 30);
#     }
#     if (window.abTCId) {
#       setCookie('abtcid', window.abTCId, daysToMinutes(365));
#     }
#   }
#
#   var onDeclineAutoTraderCookies = function () {
#     const location = window.location.href
#     var acceptATCookie = getCookie('acceptATCookies');
#     if (!acceptATCookie || acceptATCookie === 'true') {
#       setCookie('acceptATCookies', 'false', daysToMinutes(365));
#       deleteCookie('abTestGroups');
#       deleteCookie('abtcid');
#       if(location.indexOf('refresh=true') < 0) {
#         window.location = ((location.indexOf('?') > -1) ? location + '&' : '?') + 'refresh=true'
#       }
#     }
#   }
#
#   var consentsIncludeVendor = function (consentedVendors, vendorId) {
#     for (var i = 0; i < consentedVendors.length; i++) {
#       if (consentedVendors[i]._id === vendorId) {
#         return true;
#       }
#     }
#     return false;
#   }
#
#     var processAutotraderCookieConsent = function (data, success) {
#         var AUTOTRADER_VENDOR_ID = '61b20a2e5a6022094529f97b';
#         if (data && data.consentedVendors) {
#           var consent = consentsIncludeVendor(data.consentedVendors, AUTOTRADER_VENDOR_ID)
#           if (consent) {
#             onApproveAutoTraderCookies();
#           } else {
#             onDeclineAutoTraderCookies();
#           }
#         }
#     }
#
#     var processComScoreConsent = function (data, success) {
#         var COMSCORE_CONSENT_ID = '5efefe25b8e05c06542b2a77';
#         window._comscore = window._comscore || [];
#         window._comscore.push({ c1: '2', c2: '6035755', cs_ucfr: '' });
#         if (data && data.consentedVendors) {
#           consentsIncludeVendor(data.consentedVendors, COMSCORE_CONSENT_ID) ? window._comscore[0].cs_ucfr = '1' : window._comscore[0].cs_ucfr = '0';
#         }
#         (function() {
#             var s = document.createElement('script'), el = document.getElementsByTagName('script')[0];
#             s.async = true;
#             s.src = 'https://sb.scorecardresearch.com/cs/6035755/beacon.js';
#             el.parentNode.insertBefore(s, el);
#         })();
#     }
#
#   var processEachConsent = function (data, success) {
#     processAutotraderCookieConsent(data, success);
#     processComScoreConsent(data, success);
#   }
#
#   var consentCallback = function (message_type, consentUUID, euconsent) {
#       __tcfapi('getCustomVendorConsents', 2, processEachConsent);
#   }
#
#     window._sp_ = {
#         config: {
#             accountId: 741,
#             baseEndpoint: 'https://cmpv2.autotrader.co.uk',
#             events: {
#                 onConsentReady: consentCallback,
#                 onMessageChoiceSelect: function (message_type, choice_type_id) {
#                     // choice 11 is "Accept All" on CMP dialogue
#                     if (choice_type_id === 11 && window.utag && window.utag.cfg && window.utag.loader) {
#                         window.utag.cfg.nocookie = false
#                         window.utag.cfg.noload = false
#                         window.utag.loader.PINIT()
#                     }
#                 },
#                 onPrivacyManagerAction: function (pmData) {
#                     if (pmData && pmData.purposeConsent === 'all' && pmData.vendorConsent === 'all' && window.utag && window.utag.cfg && window.utag.loader) {
#                         window.utag.cfg.nocookie = false
#                         window.utag.cfg.noload = false
#                         window.utag.loader.PINIT()
#                     }
#                 }
#             }
#         }
#     }
#   </script>
#   <!--add variable to window to prevent Sourcepoint tag from loading in Tealium (corresponds to a load rule)-->
#   <script>
#    window.AT_CMP_LOADED = true
#
#         var getCookie = function (name) {
#             var value = '; ' + document.cookie
#             var parts = value.split('; ' + name + '=')
#
#             if (parts.length >= 2) return parts.pop().split(';').shift()
#         }
#
#         var readAbTestGroupsCookie = function () {
#             return getCookie('abTestGroups') || ''
#         }
#
#         var isAnonymousTrackingShielded = function () {
#             var cookieString = readAbTestGroupsCookie();
#             return cookieString && cookieString.includes('anonA')
#         };
#
#         if (!isAnonymousTrackingShielded()) {
#             window.utag_cfg_ovrd = window.utag_cfg_ovrd || {};
#             window.utag_cfg_ovrd.nocookie = true;
#             window.utag_cfg_ovrd.noload = true;
#         }
#   </script>
#   <script src="https://cmpv2.autotrader.co.uk/wrapperMessagingWithoutDetection.js">
#   </script>
#   <meta content="cars" name="channel"/>
#   <script async="" src="//tags.tiqcdn.com/utag/autotrader/at-desktop/prod/utag.js" type="text/javascript">
#   </script>
#   <script async="" charset="UTF-8" src="https://tag.contactatonce.co.uk/tag/tag.js">
#   </script>
#   <script src="https://code.jquery.com/jquery-1.11.0.min.js">
#   </script>
#   <script async="" charset="utf-8" src="/static/9690/js/_generated/bundles/5.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    #sp_message_iframe_687971 { display:block; width: 100%; height: 100%; border: 0 none; } #sp_message_container_687971 { overflow:auto;-webkit-overflow-scrolling:touch; display: none; position: fixed; z-index: 2147483647; left: 0; right: 0; bottom: 0; top: 0; height: 100%; width: 100%; max-width: 100%; max-height: 100vh;}.sp-message-open { height: 100vh !important; width: 100vw !important } .sp-message-open body { overflow: hidden !important; position: fixed !important; margin-top: 0px !important; top: 0px !important; left: 0px !important; right: 0px !important; }
#   </style>
#   <script async="" charset="UTF-8" id="_lpTagScriptId_0" src="https://tag.contactatonce.co.uk/taglets?df=0&amp;b=1&amp;providerId=245">
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://tag.contactatonce.co.uk/api/v1.0/configuration/getSdkSessionID?callback=lpTag.taglets.caoEngager.setSdkSessionId" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://tag.contactatonce.co.uk/api/v1.0/configuration/engagement?providerId=245&amp;callback=lpTag.taglets.caoEngager.loadEngagements&amp;originationUrl=https%3A%2F%2Fwww.autotrader.co.uk%2Fcar-search%3Fpostcode%3DG72%25208JD%26year-to%3D2022%26include-delivery-option%3Don%26advertising-location%3Dat_cars%26page%3D1" type="text/javascript">
#   </script>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2022081501.js">
#   </script>
#  </head>
#  <body class="new-used-experiment wide-page--search prebid-enabled is-not-logged-in new-buttons new-header-old-sauron">
#   <div id="usabilla" style="display: none;">
#   </div>
#   <script>
#    //<!--
#      document.body.className = document.body.className + ' is-not-logged-in';
#      //-->
#
#     document.body.className = document.body.className + " new-buttons";
#     document.documentElement.setAttribute('data-feature', 'new-buttons');
#   </script>
#   <span data-fbappid="1590619847851685" id="js-facebook-app-id">
#   </span>
#   <span data-fbapiversion="v3.1" id="js-facebook-api-version">
#   </span>
#   <!--[if lte IE 9]>
# <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/" class="browsehappy__link" rel="nofollow">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
#   <!-- BEGIN ContactAtOnce Integration. -->
#   <script defer="">
#    window.lpTag=window.lpTag||{},void 0===window.lpTag._tagCount?(window.lpTag={site:"p-245",env:"uk",providerId:"245",section:lpTag.section||"",autoStart:!1!==lpTag.autoStart,ovr:lpTag.ovr||{domain:"tag.contactatonce.co.uk",tagjs:""},_v:"1.0",_tagCount:1,protocol:"https:",events:{bind:function(t,e,i){lpTag.defer(function(){lpTag.events.bind(t,e,i)},0)},trigger:function(t,e,i){lpTag.defer(function(){lpTag.events.trigger(t,e,i)},1)}},defer:function(t,e){0==e?(this._defB=this._defB||[],this._defB.push(t)):1==e?(this._defT=this._defT||[],this._defT.push(t)):(this._defL=this._defL||[],this._defL.push(t))},sdk:{exec:function(t,e){lpTag._defExec=lpTag._defExec||{},lpTag._defExec[t]=lpTag._defExec[t]||[],lpTag._defExec[t].push(e)}},load:function(t,e,i){var n=this;setTimeout(function(){n._load(t,e,i)},0)},_load:function(t,e,i){var n=t;t||(n=this.protocol+"//"+(this.ovr&&this.ovr.domain?this.ovr.domain:"tag.contactatonce.com")+"/tag/tag.js");var a=document.createElement("script");a.setAttribute("charset",e||"UTF-8"),i&&a.setAttribute("id",i),a.setAttribute("src",n),a.setAttribute("async",""),document.getElementsByTagName("head").item(0).appendChild(a)},init:function(){this._timing=this._timing||{},this._timing.start=(new Date).getTime();var t=this;window.attachEvent?window.attachEvent("onload",function(){t._domReady("domReady")}):(window.addEventListener("DOMContentLoaded",function(){t._domReady("contReady")},!1),window.addEventListener("load",function(){t._domReady("domReady")},!1)),void 0===window._caotStop&&this.load()},start:function(){this.autoStart=!0},_domReady:function(t){this.isDom||(this.isDom=!0,this.events.trigger("CAOT","DOM_READY",{t:t})),this._timing[t]=(new Date).getTime()},vars:lpTag.vars||[],dbs:lpTag.dbs||[],ctn:lpTag.ctn||[],sdes:lpTag.sdes||[],ev:lpTag.ev||[],tagletCommands:lpTag.tagletCommands||[]},lpTag.init()):window.lpTag._tagCount+=1;
#   </script>
#   <!-- END ContactAtOnce Integration. -->
#   <script>
#    (function() {
#         var bodyEl = document.querySelector('body');
#         bodyEl.classList.add('new-header-old-sauron');
#     })();
#   </script>
#   <section class="atds-header-wrapper group">
#    <header class="atds-header">
#     <p class="visuallyhidden">
#      Currently in the cars channel
#     </p>
#     <a class="visuallyhidden focusable" href="#content">
#      Skip to content
#     </a>
#     <a class="visuallyhidden focusable" href="#footer">
#      Skip to footer
#     </a>
#     <nav aria-hidden="false" aria-labelledby="primary-navigation" id="atds-navigation" role="navigation">
#      <div class="atds-nav-wrapper">
#       <div class="atds-header__group">
#        <!-- logo and link -->
#        <a class="atds-header__logo" href="/">
#         <svg class="atds-svg atds-logo" height="20" viewbox="0 0 156 20" width="156" xmlns="http://www.w3.org/2000/svg">
#          <title>
#           Auto Trader Logo
#          </title>
#          <g fill="none" fill-rule="evenodd">
#           <path d="M-3-7h162v36H-3">
#           </path>
#           <path d="M46.364 5.897v7.6c0 1.01.217 1.772.651 2.286.434.514 1.077.771 1.928.771.85 0 1.493-.257 1.927-.77.398-.472.614-1.152.647-2.04l.004-.247v-7.6h3.191v7.812c0 1.702-.532 3.062-1.595 4.081-1.064 1.02-2.455 1.53-4.174 1.53-1.72 0-3.11-.51-4.174-1.53-1.001-.959-1.531-2.22-1.59-3.784l-.005-.297V5.897h3.19zm26.767-.695c1.95 0 3.58.634 4.892 1.9 1.238 1.198 1.892 2.73 1.961 4.6l.006.332v.479c0 2.003-.656 3.638-1.967 4.905-1.312 1.268-2.942 1.901-4.892 1.901-1.95 0-3.567-.629-4.852-1.888-1.214-1.188-1.854-2.717-1.921-4.585l-.006-.333v-.479c0-2.02.642-3.664 1.927-4.931 1.285-1.267 2.902-1.901 4.852-1.901zm66.277 0c1.861 0 3.385.62 4.573 1.861 1.187 1.24 1.78 2.854 1.78 4.839 0 .195-.004.407-.012.638l-.017.352-.023.365h-9.625c.142 1.082.514 1.924 1.117 2.526.603.603 1.382.904 2.34.904.762 0 1.373-.133 1.834-.399a2.46 2.46 0 0 0 .723-.644l.12-.168h3.258c-.373 1.154-1.038 2.064-2 2.726-1.082.745-2.429 1.117-4.042 1.117-1.896 0-3.478-.647-4.745-1.94-1.197-1.222-1.829-2.745-1.895-4.568l-.006-.325v-.425c0-1.967.633-3.602 1.9-4.905 1.268-1.303 2.84-1.954 4.72-1.954zM130.65.46v18.434h-2.472l-.452-1.49h-.053a4.652 4.652 0 0 1-1.874 1.45c-.736.31-1.6.465-2.593.465-1.719 0-3.19-.638-4.413-1.914-1.15-1.201-1.76-2.693-1.828-4.475l-.006-.337v-.505c0-2.02.607-3.673 1.821-4.959 1.214-1.284 2.778-1.927 4.692-1.927.886 0 1.644.12 2.273.359.55.21 1.037.517 1.459.923l.177.18h.053V.46h3.216zm-22.963 4.742c.868 0 1.661.16 2.379.478.628.28 1.219.688 1.773 1.225l.235.238h.052l.532-1.542h2.34v13.293h-2.5l-.504-1.596h-.054a4.365 4.365 0 0 1-1.807 1.49c-.745.336-1.595.504-2.553.504-1.737 0-3.203-.628-4.4-1.887-1.125-1.184-1.722-2.683-1.788-4.495l-.006-.344v-.478c0-1.985.593-3.63 1.781-4.932 1.187-1.303 2.694-1.954 4.52-1.954zm-46.32-2.958v3.004h3.378v2.499h-3.377v7.212c0 .496.12.868.36 1.117.238.248.606.372 1.102.372.32 0 .63-.049.93-.146.242-.078.488-.193.74-.345l.191-.121h.452v2.632c-.319.178-.753.333-1.303.466-.55.133-1.01.2-1.382.2-1.436 0-2.517-.373-3.243-1.118-.679-.695-1.04-1.714-1.086-3.056l-.005-.293v-6.92h-1.808V6.284c.851-.407 1.56-.92 2.127-1.541.505-.552.96-1.271 1.366-2.159l.15-.34h1.409zM91.86 1.26v2.898h-4.892v14.736h-3.35V4.158h-5.104V1.26H91.86zm7.298 4.234a8.869 8.869 0 0 1 .974.067l.09.013v3.164h-1.197c-1.187 0-2.043.261-2.565.784-.489.488-.749 1.397-.781 2.726l-.004.292v6.354h-3.217V5.6h2.287l.69 2.552h.054a3.112 3.112 0 0 1 1.276-1.941c.673-.479 1.471-.718 2.393-.718zm55.523 0a8.398 8.398 0 0 1 .974.066l.09.014v3.164h-1.197c-1.187 0-2.043.262-2.565.784-.488.488-.749 1.397-.781 2.727l-.004.29v6.355h-3.217V5.6h2.287l.691 2.552h.053a3.11 3.11 0 0 1 1.276-1.94c.674-.48 1.471-.719 2.393-.719zM35.332 1.613l6.806 16.855v.426h-3.43l-1.329-3.51-.282-.75h-7.171l-.284.753-1.329 3.507h-3.296v-.426l6.806-16.855h3.51zM22.128 11.717l-1.577 3.905c-.799 1.9-2.593 3.238-4.668 3.268L.26 18.894l2.898-7.177h18.97zm86.064-3.91c-1.153 0-2.047.399-2.685 1.197-.638.797-.957 1.879-.957 3.243 0 1.365.319 2.442.957 3.23.638.79 1.532 1.184 2.685 1.184 1.134 0 2.025-.395 2.672-1.184.647-.788.97-1.865.97-3.23 0-1.364-.323-2.446-.97-3.243-.647-.798-1.538-1.197-2.672-1.197zm15.653 0c-1.153 0-2.047.399-2.686 1.197-.638.797-.957 1.879-.957 3.243 0 1.365.32 2.442.957 3.23.639.79 1.533 1.184 2.686 1.184 1.134 0 2.024-.395 2.672-1.184.646-.788.97-1.865.97-3.23 0-1.364-.324-2.446-.97-3.243-.648-.798-1.538-1.197-2.672-1.197zm-50.687.053c-1.117 0-1.99.395-2.619 1.184-.63.788-.944 1.856-.944 3.203 0 1.347.314 2.415.944 3.204.629.789 1.502 1.183 2.619 1.183 1.116 0 1.994-.394 2.632-1.183.638-.789.957-1.857.957-3.204 0-1.347-.32-2.415-.957-3.203-.638-.789-1.516-1.184-2.632-1.184zM33.55 4.91h-.053c-.071.301-.169.633-.293.996-.11.323-.284.797-.52 1.42l-.091.242-1.572 4.164h4.986l-1.553-4.164a132.1 132.1 0 0 1-.705-1.98 9.376 9.376 0 0 1-.2-.679zm105.963 2.924c-.886 0-1.608.24-2.167.718-.507.435-.88 1.075-1.116 1.92l-.067.26h6.301c-.053-.904-.341-1.613-.864-2.127-.523-.514-1.219-.771-2.087-.771z" fill="#222B5E">
#           </path>
#           <path d="M26.209 1.613l-15.623.002c-2.075.031-3.868 1.368-4.668 3.267L4.341 8.789h18.97l2.898-7.176z" fill="#B11212">
#           </path>
#          </g>
#         </svg>
#        </a>
#        <!-- tools-->
#        <div class="atds-header-tools wide-hide">
#         <button aria-controls="atc-navigation" aria-expanded="false" aria-haspopup="true" aria-label="Show mobile menu" class="atds-menu-btn atds-type-mini atds-header-tools__link atds-header-tools__link--menu" data-gui-header-btn-toggle-mobile-nav="true">
#          <div aria-hidden="true" class="atds-menu-btn__outer">
#           <div aria-hidden="true" class="atds-menu-btn__inner">
#           </div>
#          </div>
#          <span>
#           <span class="visuallyhidden">
#            Open / close
#           </span>
#           Menu
#          </span>
#         </button>
#         <a class="atds-type-mini atds-header-tools__link" href="/sell-my-car">
#          <svg class="atds-svg" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
#           <title>
#           </title>
#           <path d="M9.1982 11.1807C8.9382 11.1807 8.6982 11.0997 8.4882 11.0207C8.2882 10.9407 8.0972 10.8607 7.8882 10.7897C7.9382 10.5597 7.9582 10.2897 7.9582 9.96969C7.9582 9.70069 7.9082 9.45069 7.8282 9.20069H9.3282V8.43069H7.4982C7.2482 8.02069 7.0282 7.61069 7.0282 7.16969C7.0282 6.56069 7.3582 6.04969 8.0782 6.04969C8.8382 6.04969 9.1282 6.47969 9.1282 7.18069V7.22969H10.0082V7.12969C10.0082 6.02069 9.2672 5.27069 8.0972 5.27069C6.8472 5.27069 6.0882 6.02069 6.0882 7.11969V7.24969C6.0882 7.63969 6.2682 8.09069 6.4482 8.43069H5.8582V9.20069H6.8582C6.9882 9.46969 7.0882 9.75969 7.0882 10.0597C7.0882 10.2497 7.0682 10.4507 7.0492 10.6197H6.9782C6.0882 10.6507 5.6982 11.1807 5.7382 11.9197H6.5972C6.5972 11.5897 6.7782 11.4407 7.1772 11.4407C7.5382 11.4407 7.7672 11.5697 8.0882 11.7007C8.4082 11.8497 8.7282 11.9997 9.1882 11.9997C10.2192 11.9997 10.5682 11.3097 10.5972 10.6197V10.4997H9.7782C9.7982 10.9097 9.6282 11.1807 9.1982 11.1807ZM1.333 14V3.99999H4C4.231 3.99999 4.425 3.87499 4.545 3.69599L4.555 3.70299L5.69 1.99999H10.31L11.445 3.70299L11.455 3.69599C11.575 3.87499 11.769 3.99999 12 3.99999H14.667V14H1.333ZM14.667 2.66699H12.356L11.222 0.963992L11.211 0.970992C11.092 0.791992 10.897 0.666992 10.667 0.666992H5.333C5.103 0.666992 4.908 0.791992 4.789 0.970992L4.778 0.963992L3.644 2.66699H1.333C0.599 2.66699 0 3.26499 0 3.99999V14C0 14.735 0.599 15.333 1.333 15.333H14.667C15.401 15.333 16 14.735 16 14V3.99999C16 3.26499 15.401 2.66699 14.667 2.66699Z">
#           </path>
#          </svg>
#          Sell
#         </a>
#        </div>
#        <div class="atds-header-tools">
#         <a aria-label="Go to your saved adverts" class="atds-type-mini atds-header-tools__link" href="/secure/saved-adverts">
#          <svg class="atds-svg" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
#           <path d="M8 14.185C5.115 11.428 1.333 6.968 1.333 4.454C1.333 2.298 2.713 1.333 4.081 1.333C5.1 1.333 6.157 1.83 7.058 2.73L8 3.672L8.942 2.73C9.843 1.83 10.9 1.333 11.919 1.333C13.287 1.333 14.667 2.298 14.667 4.454C14.667 6.964 10.884 11.426 8 14.185ZM11.919 0C10.632 0 9.226 0.561 8 1.787C6.774 0.561 5.369 0 4.081 0C1.866 0 0 1.661 0 4.454C0 8.872 8 16 8 16C8 16 16 8.872 16 4.454C16 1.66 14.134 0 11.919 0Z">
#           </path>
#          </svg>
#          Saved
#         </a>
#         <a class="atds-type-mini atds-header-tools__link wide-hide" href="/search-form">
#          <svg class="atds-svg" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
#           <title>
#           </title>
#           <path d="M6 10.667C3.427 10.667 1.333 8.573 1.333 6C1.333 3.427 3.427 1.333 6 1.333C8.573 1.333 10.667 3.427 10.667 6C10.667 8.573 8.573 10.667 6 10.667ZM10.686 9.742C11.506 8.716 12 7.416 12 6C12 2.687 9.313 0 6 0C2.687 0 0 2.687 0 6C0 9.313 2.687 12 6 12C7.417 12 8.716 11.506 9.742 10.686L15.058 16L16 15.057L10.686 9.742Z">
#           </path>
#          </svg>
#          Search
#         </a>
#         <a aria-label="Sign in to your Auto Trader Account" class="atds-header-tools__link atds-type-mini narrow-hide" href="/secure/signin">
#          <svg class="atds-svg" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
#           <path d="M8 6.6666C7.265 6.6666 6.667 6.0676 6.667 5.3326C6.667 4.5976 7.265 3.9996 8 3.9996C8.735 3.9996 9.333 4.5976 9.333 5.3326C9.333 6.0676 8.735 6.6666 8 6.6666ZM8 2.6666C6.527 2.6666 5.333 3.8596 5.333 5.3326C5.333 6.8056 6.527 7.9996 8 7.9996C9.473 7.9996 10.667 6.8056 10.667 5.3326C10.667 3.8596 9.473 2.6666 8 2.6666ZM12.8823 12.524C12.0573 10.646 10.1833 9.333 8.0003 9.333C5.8173 9.333 3.9433 10.646 3.1173 12.524C2.0143 11.334 1.3333 9.747 1.3333 8C1.3333 5.427 2.7703 3.129 5.0843 2.003C5.9953 1.558 6.9763 1.333 8.0003 1.333C11.6753 1.333 14.6673 4.324 14.6673 8C14.6673 9.747 13.9863 11.334 12.8823 12.524ZM8.0003 14.667C6.5823 14.667 5.2683 14.217 4.1863 13.46C4.6993 11.842 6.2153 10.667 8.0003 10.667C9.7853 10.667 11.3003 11.842 11.8133 13.46C10.7313 14.217 9.4183 14.667 8.0003 14.667ZM8.0003 0C6.7453 0 5.5573 0.289 4.5003 0.804C1.8363 2.102 0.000301361 4.837 0.000301361 8C0.000301361 10.389 1.0533 12.527 2.7143 13.994C3.1133 14.346 3.5483 14.661 4.0133 14.928C5.1883 15.606 6.5473 16 8.0003 16C9.4533 16 10.8123 15.606 11.9863 14.928C12.4523 14.661 12.8863 14.346 13.2863 13.994C14.9473 12.527 16.0003 10.389 16.0003 8C16.0003 3.582 12.4183 0 8.0003 0Z">
#           </path>
#          </svg>
#          Sign in
#         </a>
#         <a class="atds-header-tools-security atds-type-smart wide-hide" href="/safety_and_security_centre" role="menuitem">
#          <span class="atds-header__label">
#           Security advice
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="narrow-hide">
#        <!-- channel switcher-->
#        <ul aria-labelledby="channel-switcher-heading" class="atds-channel-switcher atds-type-mini" role="menu">
#         <li class="atds-channel-switcher__item" role="none">
#          <a aria-current="true" class="atds-channel-switcher__link atds-channel-switcher__link--selected tracking-navigation-link" data-label="cars" href="/" role="menuitem">
#           Cars
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="vans" href="/vans" role="menuitem">
#           Vans
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="bikes" href="/bikes" role="menuitem">
#           Bikes
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="motorhomes" href="/motorhomes" role="menuitem">
#           Motorhomes
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="caravans" href="/caravans" role="menuitem">
#           Caravans
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="trucks" href="/trucks" role="menuitem">
#           Trucks
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="farm" href="/farm" role="menuitem">
#           Farm
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="plant" href="/plant" role="menuitem">
#           Plant
#          </a>
#         </li>
#         <li class="atds-channel-switcher__item" role="none">
#          <a class="atds-channel-switcher__link tracking-navigation-link" data-label="security advice" href="/safety_and_security_centre" role="menuitem">
#           Security advice
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="atds-header__drawer">
#        <h2 class="visuallyhidden" id="primary-navigation">
#         Main site menu
#        </h2>
#        <div class="atds-drawer-account wide-hide">
#         <a class="atds-login-button" href="/secure/my-auto-trader">
#          <svg class="atds-svg" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
#           <title>
#           </title>
#           <path d="M8 6.6666C7.265 6.6666 6.667 6.0676 6.667 5.3326C6.667 4.5976 7.265 3.9996 8 3.9996C8.735 3.9996 9.333 4.5976 9.333 5.3326C9.333 6.0676 8.735 6.6666 8 6.6666ZM8 2.6666C6.527 2.6666 5.333 3.8596 5.333 5.3326C5.333 6.8056 6.527 7.9996 8 7.9996C9.473 7.9996 10.667 6.8056 10.667 5.3326C10.667 3.8596 9.473 2.6666 8 2.6666ZM12.8823 12.524C12.0573 10.646 10.1833 9.333 8.0003 9.333C5.8173 9.333 3.9433 10.646 3.1173 12.524C2.0143 11.334 1.3333 9.747 1.3333 8C1.3333 5.427 2.7703 3.129 5.0843 2.003C5.9953 1.558 6.9763 1.333 8.0003 1.333C11.6753 1.333 14.6673 4.324 14.6673 8C14.6673 9.747 13.9863 11.334 12.8823 12.524ZM8.0003 14.667C6.5823 14.667 5.2683 14.217 4.1863 13.46C4.6993 11.842 6.2153 10.667 8.0003 10.667C9.7853 10.667 11.3003 11.842 11.8133 13.46C10.7313 14.217 9.4183 14.667 8.0003 14.667ZM8.0003 0C6.7453 0 5.5573 0.289 4.5003 0.804C1.8363 2.102 0.000301361 4.837 0.000301361 8C0.000301361 10.389 1.0533 12.527 2.7143 13.994C3.1133 14.346 3.5483 14.661 4.0133 14.928C5.1883 15.606 6.5473 16 8.0003 16C9.4533 16 10.8123 15.606 11.9863 14.928C12.4523 14.661 12.8863 14.346 13.2863 13.994C14.9473 12.527 16.0003 10.389 16.0003 8C16.0003 3.582 12.4183 0 8.0003 0Z">
#           </path>
#          </svg>
#          My Auto Trader
#         </a>
#        </div>
#        <h3 class="visuallyhidden" id="channel-switcher-heading">
#         Vehicle types selection
#        </h3>
#        <div class="wide-hide">
#         <!-- channel switcher-->
#         <ul aria-labelledby="channel-switcher-heading" class="atds-channel-switcher atds-type-mini" role="menu">
#          <li class="atds-channel-switcher__item" role="none">
#           <a aria-current="true" class="atds-channel-switcher__link atds-channel-switcher__link--selected tracking-navigation-link" data-label="cars" href="/" role="menuitem">
#            Cars
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="vans" href="/vans" role="menuitem">
#            Vans
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="bikes" href="/bikes" role="menuitem">
#            Bikes
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="motorhomes" href="/motorhomes" role="menuitem">
#            Motorhomes
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="caravans" href="/caravans" role="menuitem">
#            Caravans
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="trucks" href="/trucks" role="menuitem">
#            Trucks
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="farm" href="/farm" role="menuitem">
#            Farm
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="plant" href="/plant" role="menuitem">
#            Plant
#           </a>
#          </li>
#          <li class="atds-channel-switcher__item" role="none">
#           <a class="atds-channel-switcher__link tracking-navigation-link" data-label="security advice" href="/safety_and_security_centre" role="menuitem">
#            Security advice
#           </a>
#          </li>
#         </ul>
#        </div>
#        <p class="visuallyhidden">
#         Currently in the cars channel
#        </p>
#        <!-- primary nav -->
#        <ul class="atds-primary-navigation atds-type-prius atds-primary-navigation--active" id="menu-nav" role="menubar">
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="used cars" href="/cars/used">
#           Used cars
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="new cars" href="/cars/new">
#           New cars
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="sell your car" href="/cars/sell">
#           Sell your car
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="value your car" href="/cars/valuation">
#           Value your car
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="car reviews" href="/cars/reviews">
#           Car reviews
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="car leasing" href="/cars/leasing">
#           Car leasing
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="electric cars" href="/cars/electric">
#           Electric cars
#          </a>
#         </li>
#         <li class="atds-primary-navigation__item" role="menuitem">
#          <a class="atds-primary-navigation__link tracking-navigation-link" data-label="buy a car online" href="/cars/buying-online">
#           Buy a car online
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#   </section>
#   <iframe name="__tcfapiLocator" style="display: none;">
#   </iframe>
#   <nav class="breadcrumbs js-top-scroll-anchor">
#    <ul class="breadcrumbs__list">
#     <li class="breadcrumbs__list-item">
#      <a class="breadcrumbs__link tracking-navigation-link" href="/">
#       Home
#      </a>
#     </li>
#     <li class="breadcrumbs__list-item">
#      <a class="breadcrumbs__link tracking-navigation-link" href="/search-form">
#       Buying
#      </a>
#     </li>
#     <li class="breadcrumbs__list-item">
#      Search results
#     </li>
#    </ul>
#   </nav>
#   <script type="application/ld+json">
#    {
#  "@context": "http://schema.org",
#  "@type": "BreadcrumbList",
#  "itemListElement":
#     [
#             {
#              "@type": "ListItem",
#               "position": 1,
#               "item":
#                   {
#                     "@id" : "/",
#                     "name" : "Home"
#                   }
#             }
#         ,            {
#              "@type": "ListItem",
#               "position": 2,
#               "item":
#                   {
#                     "@id" : "/search-form",
#                     "name" : "Buying"
#                   }
#             }
#         ,            {
#              "@type": "ListItem",
#               "position": 3,
#               "item":
#                   {
#                     "@id" : "/car-search",
#                     "name" : "Search results"
#                   }
#             }
#
#     ]
# }
#   </script>
#   <main class="search-page js-searchone-page flyoutWindowScroll at-rebrand search-page--full-width">
#    <div class="search-page__wrapper">
#     <section class="search-page__left search-page__left--full-width">
#      <div class="search-form">
#       <form action="https://www.autotrader.co.uk:443/results-car-search" class="search-form__form js-search-form is-header-expanded" method="post">
#        <div class="search-form__header">
#         <div class="search-form__header-content">
#          <h1 class="search-form__count js-results-count">
#           404,741 cars for sale
#          </h1>
#          <p class="search-form__filter-count js-filter-count">
#          </p>
#          <div class="search-form__reset-results">
#           <a class="js-save-search save-search-button search-form__save-search tracking-standard-link search-form__save-search-top" href="https://www.autotrader.co.uk:443/secure/signin?channel=cars&amp;regj=SAVE_SEARCH&amp;after-signin-url=">
#            <i class="icon-star-fill">
#             <svg class="star-icon">
#              <title>
#               Star save icon
#              </title>
#              <use xlink:href="/templates/_generated/svg_icons/common.svg#icon-star-save-filled">
#              </use>
#             </svg>
#            </i>
#            Save search
#           </a>
#           <a class="js-reset search-form__reset-top tracking-standard-link" href="/car-search">
#            <i class="icon-reset">
#             <svg>
#              <use xlink:href="/templates/_generated/svg_icons/common.svg#icon-refresh">
#              </use>
#             </svg>
#            </i>
#            Reset
#           </a>
#          </div>
#         </div>
#        </div>
#        <ul class="search-form__fields-list">
#         <input id="sort" name="sort" type="hidden" value="relevance"/>
#         <li>
#          <fieldset class="search-form__location-fieldset">
#           <div class="search-form__location-field">
#            <input class="input" data-default-value="valid" id="postcode" name="postcode" placeholder="Postcode" type="text" value="G72 8JD"/>
#           </div>
#           <div class="search-form__location-field">
#            <div class="selectbox">
#             <select class="js-selectbox selectbox__select js-search-option" data-field-name="radius" name="radius">
#              <option value="1500">
#               Distance (national)
#              </option>
#              <option value="1">
#               Within 1 mile
#              </option>
#              <option value="5">
#               Within 5 miles
#              </option>
#              <option value="10">
#               Within 10 miles
#              </option>
#              <option value="15">
#               Within 15 miles
#              </option>
#              <option value="20">
#               Within 20 miles
#              </option>
#              <option value="25">
#               Within 25 miles
#              </option>
#              <option value="30">
#               Within 30 miles
#              </option>
#              <option value="35">
#               Within 35 miles
#              </option>
#              <option value="40">
#               Within 40 miles
#              </option>
#              <option value="45">
#               Within 45 miles
#              </option>
#              <option value="50">
#               Within 50 miles
#              </option>
#              <option value="55">
#               Within 55 miles
#              </option>
#              <option value="60">
#               Within 60 miles
#              </option>
#              <option value="70">
#               Within 70 miles
#              </option>
#              <option value="80">
#               Within 80 miles
#              </option>
#              <option value="90">
#               Within 90 miles
#              </option>
#              <option value="100">
#               Within 100 miles
#              </option>
#              <option value="200">
#               Within 200 miles
#              </option>
#             </select>
#             <div class="js-selectbox__label selectbox__label">
#              Distance (national)
#             </div>
#            </div>
#           </div>
#          </fieldset>
#         </li>
#         <li>
#          <div class="flyout-menu js-search-option" data-field-name="make" data-has-options="false">
#           <button class="options-button js-button" data-button-for="make" type="button">
#            <span class="options-button__inner">
#             <span class="options-button__name">
#              Make
#             </span>
#             <span class="options-button__value js-selected-value">
#              Any
#             </span>
#             <span class="options-button__icon">
#              <i class="icon-arrow-right js-button-icon">
#               <svg>
#                <use xlink:href="/templates/_generated/svg_icons/common.svg#icon-arrow-right">
#                </use>
#               </svg>
#              </i>
#             </span>
#            </span>
#           </button>
#           <div class="flyout js-flyout" data-temp="make-flyout">
#            <span class="flyout__arrow">
#            </span>
#            <header class="flyout__header">
#             <h2 class="flyout__title">
#              Select Make
#             </h2>
#             <div class="right">
#              <button class="sf-flyout__close js-close" type="button">
#               Close
#               <i class="icon-x">
#               </i>
#              </button>
#             </div>
#            </header>
#            <input class="input flyout__filter-input tracking-standard-link" data-label="search type to filter" placeholder="type to filter" type="text"/>
#            <div class="sf-flyout__scrollable-options js-flyout-scrollable-options">
#             <div class="sf-flyout__options js-flyout-options">
#              <button class="value-button js-value-button" data-selected-display-name="AC" data-selected-value="AC" tabindex="0" type="button">
#               <span class="term">
#                AC
#               </span>
#               <span class="count">
#                (6)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Abarth" data-selected-value="Abarth" tabindex="0" type="button">
#               <span class="term">
#                Abarth
#               </span>
#               <span class="count">
#                (799)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Aixam" data-selected-value="Aixam" tabindex="0" type="button">
#               <span class="term">
#                Aixam
#               </span>
#               <span class="count">
#                (1)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Alfa Romeo" data-selected-value="Alfa Romeo" tabindex="0" type="button">
#               <span class="term">
#                Alfa Romeo
#               </span>
#               <span class="count">
#                (1,325)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Alpine" data-selected-value="Alpine" tabindex="0" type="button">
#               <span class="term">
#                Alpine
#               </span>
#               <span class="count">
#                (24)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Alvis" data-selected-value="Alvis" tabindex="0" type="button">
#               <span class="term">
#                Alvis
#               </span>
#               <span class="count">
#                (1)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Ariel" data-selected-value="Ariel" tabindex="0" type="button">
#               <span class="term">
#                Ariel
#               </span>
#               <span class="count">
#                (7)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Aston Martin" data-selected-value="Aston Martin" tabindex="0" type="button">
#               <span class="term">
#                Aston Martin
#               </span>
#               <span class="count">
#                (888)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Audi" data-selected-value="Audi" tabindex="0" type="button">
#               <span class="term">
#                Audi
#               </span>
#               <span class="count">
#                (31,751)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Austin" data-selected-value="Austin" tabindex="0" type="button">
#               <span class="term">
#                Austin
#               </span>
#               <span class="count">
#                (33)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Bac" data-selected-value="BAC" tabindex="0" type="button">
#               <span class="term">
#                Bac
#               </span>
#               <span class="count">
#                (2)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="BMW" data-selected-value="BMW" tabindex="0" type="button">
#               <span class="term">
#                BMW
#               </span>
#               <span class="count">
#                (36,245)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Beauford" data-selected-value="Beauford" tabindex="0" type="button">
#               <span class="term">
#                Beauford
#               </span>
#               <span class="count">
#                (3)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Bentley" data-selected-value="Bentley" tabindex="0" type="button">
#               <span class="term">
#                Bentley
#               </span>
#               <span class="count">
#                (1,143)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Bowler" data-selected-value="Bowler" tabindex="0" type="button">
#               <span class="term">
#                Bowler
#               </span>
#               <span class="count">
#                (2)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Bugatti" data-selected-value="Bugatti" tabindex="0" type="button">
#               <span class="term">
#                Bugatti
#               </span>
#               <span class="count">
#                (3)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Buick" data-selected-value="Buick" tabindex="0" type="button">
#               <span class="term">
#                Buick
#               </span>
#               <span class="count">
#                (2)
#               </span>
#              </button>
#              <button class="value-button js-value-button" data-selected-display-name="Cfmoto" data-selected-value="CFMOTO" tabindex="0" type="button">
#               <span class="term">
#                Cfmoto
#               </span>
#               <span class="count">
#                (1)
#               </span>
#              </button>
# ...
#          <title>
#           hp-download-ios-app
#          </title>
#         </path>
#        </svg>
#       </a>
#       <a class="tracking-footer-link" data-label="hp-download-android-app" href="https://play.google.com/store/apps/details?id=uk.co.autotrader.androidconsumersearch&amp;referrer=utm_source%3DMobile%2520Web%2520homepage" rel="noopener noreferrer" target="_blank">
#        <svg height="40" width="135" xmlns="http://www.w3.org/2000/svg">
#         <path d="M130 40H5c-2.8 0-5-2.2-5-5V5c0-2.8 2.2-5 5-5h125c2.8 0 5 2.2 5 5v30c0 2.8-2.2 5-5 5z">
#          <title>
#           hp-download-android-app
#          </title>
#         </path>
#         <path d="M130 .8c2.3 0 4.2 1.9 4.2 4.2v30c0 2.3-1.9 4.2-4.2 4.2H5C2.7 39.2.8 37.3.8 35V5C.8 2.7 2.7.8 5 .8h125m0-.8H5C2.2 0 0 2.2 0 5v30c0 2.8 2.2 5 5 5h125c2.8 0 5-2.2 5-5V5c0-2.8-2.2-5-5-5z" fill="#A6A6A6">
#          <title>
#           hp-download-android-app
#          </title>
#         </path>
#         <path d="M47.4 10.2c0 .8-.2 1.5-.7 2-.6.6-1.3.9-2.2.9-.9 0-1.6-.3-2.2-.9-.6-.6-.9-1.3-.9-2.2 0-.9.3-1.6.9-2.2.6-.6 1.3-.9 2.2-.9.4 0 .8.1 1.2.3.4.2.7.4.9.7l-.5.5c-.4-.5-.9-.7-1.6-.7-.6 0-1.2.2-1.6.7s-.7 1-.7 1.7.2 1.3.7 1.7 1 .7 1.6.7c.7 0 1.2-.2 1.7-.7.3-.3.5-.7.5-1.2h-2.2v-.8h2.9v.4zM52 7.7h-2.7v1.9h2.5v.7h-2.5v1.9H52v.8h-3.5V7H52v.7zm3.3 5.3h-.8V7.7h-1.7V7H57v.7h-1.7V13zm4.6 0V7h.8v6h-.8zm4.2 0h-.8V7.7h-1.7V7h4.1v.7H64V13zm9.5-.8c-.6.6-1.3.9-2.2.9s-1.6-.3-2.2-.9c-.6-.6-.9-1.3-.9-2.2s.3-1.6.9-2.2c.6-.6 1.3-.9 2.2-.9.9 0 1.6.3 2.2.9.6.6.9 1.3.9 2.2 0 .9-.3 1.6-.9 2.2zm-3.8-.5c.4.4 1 .7 1.6.7s1.2-.2 1.6-.7c.4-.4.7-1 .7-1.7s-.2-1.3-.7-1.7c-.4-.4-1-.7-1.6-.7s-1.2.2-1.6.7c-.4.4-.7 1-.7 1.7s.2 1.3.7 1.7zm5.8 1.3V7h.9l2.9 4.7V7h.8v6h-.8l-3.1-4.9V13h-.7z" fill="#FFF" stroke="#FFF" stroke-miterlimit="10" stroke-width=".2">
#          <title>
#           hp-download-android-app
#          </title>
#         </path>
#         <path d="M68.1 21.8c-2.4 0-4.3 1.8-4.3 4.3 0 2.4 1.9 4.3 4.3 4.3s4.3-1.8 4.3-4.3c0-2.6-1.9-4.3-4.3-4.3zm0 6.8c-1.3 0-2.4-1.1-2.4-2.6s1.1-2.6 2.4-2.6c1.3 0 2.4 1 2.4 2.6 0 1.5-1.1 2.6-2.4 2.6zm-9.3-6.8c-2.4 0-4.3 1.8-4.3 4.3 0 2.4 1.9 4.3 4.3 4.3s4.3-1.8 4.3-4.3c0-2.6-1.9-4.3-4.3-4.3zm0 6.8c-1.3 0-2.4-1.1-2.4-2.6s1.1-2.6 2.4-2.6c1.3 0 2.4 1 2.4 2.6 0 1.5-1.1 2.6-2.4 2.6zm-11.1-5.5v1.8H52c-.1 1-.5 1.8-1 2.3-.6.6-1.6 1.3-3.3 1.3-2.7 0-4.7-2.1-4.7-4.8s2.1-4.8 4.7-4.8c1.4 0 2.5.6 3.3 1.3l1.3-1.3c-1.1-1-2.5-1.8-4.5-1.8-3.6 0-6.7 3-6.7 6.6 0 3.6 3.1 6.6 6.7 6.6 2 0 3.4-.6 4.6-1.9 1.2-1.2 1.6-2.9 1.6-4.2 0-.4 0-.8-.1-1.1h-6.2zm45.4 1.4c-.4-1-1.4-2.7-3.6-2.7s-4 1.7-4 4.3c0 2.4 1.8 4.3 4.2 4.3 1.9 0 3.1-1.2 3.5-1.9l-1.5-1c-.5.7-1.1 1.2-2.1 1.2s-1.6-.4-2.1-1.3l5.7-2.4-.1-.5zm-5.8 1.4c0-1.6 1.3-2.5 2.2-2.5.7 0 1.4.4 1.6.9l-3.8 1.6zM82.6 30h1.9V17.5h-1.9V30zm-3-7.3c-.5-.5-1.3-1-2.3-1-2.1 0-4.1 1.9-4.1 4.3s1.9 4.2 4.1 4.2c1 0 1.8-.5 2.2-1h.1v.6c0 1.6-.9 2.5-2.3 2.5-1.1 0-1.9-.8-2.1-1.5l-1.6.7c.5 1.1 1.7 2.5 3.8 2.5 2.2 0 4-1.3 4-4.4V22h-1.8v.7zm-2.2 5.9c-1.3 0-2.4-1.1-2.4-2.6s1.1-2.6 2.4-2.6c1.3 0 2.3 1.1 2.3 2.6s-1 2.6-2.3 2.6zm24.4-11.1h-4.5V30h1.9v-4.7h2.6c2.1 0 4.1-1.5 4.1-3.9s-2-3.9-4.1-3.9zm.1 6h-2.7v-4.3h2.7c1.4 0 2.2 1.2 2.2 2.1-.1 1.1-.9 2.2-2.2 2.2zm11.5-1.8c-1.4 0-2.8.6-3.3 1.9l1.7.7c.4-.7 1-.9 1.7-.9 1 0 1.9.6 2 1.6v.1c-.3-.2-1.1-.5-1.9-.5-1.8 0-3.6 1-3.6 2.8 0 1.7 1.5 2.8 3.1 2.8 1.3 0 1.9-.6 2.4-1.2h.1v1h1.8v-4.8c-.2-2.2-1.9-3.5-4-3.5zm-.2 6.9c-.6 0-1.5-.3-1.5-1.1 0-1 1.1-1.3 2-1.3.8 0 1.2.2 1.7.4-.2 1.2-1.2 2-2.2 2zm10.5-6.6l-2.1 5.4h-.1l-2.2-5.4h-2l3.3 7.6-1.9 4.2h1.9l5.1-11.8h-2zm-16.8 8h1.9V17.5h-1.9V30z" fill="#FFF">
#          <title>
#           hp-download-android-app
#          </title>
#         </path>
#         <lineargradient gradienttransform="matrix(1 0 0 -1 0 182)" gradientunits="userSpaceOnUse" id="a" x1="21.801" x2="5.019" y1="173.291" y2="156.509">
#          <stop offset="0" stop-color="#00A0FF">
#          </stop>
#          <stop offset=".007" stop-color="#00A1FF">
#          </stop>
#          <stop offset=".26" stop-color="#00BEFF">
#          </stop>
#          <stop offset=".512" stop-color="#00D2FF">
#          </stop>
#          <stop offset=".76" stop-color="#00DFFF">
#          </stop>
#          <stop offset="1" stop-color="#00E3FF">
#          </stop>
#         </lineargradient>
#         <path d="M10.4 7.5c-.3.3-.4.8-.4 1.4V31c0 .6.2 1.1.5 1.4l.1.1L23 20.1v-.2L10.4 7.5z" fill="url(#a)">
#          <title>
#           hp-download-android-app
#          </title>
#         </path>
#         <lineargradient gradienttransform="matrix(1 0 0 -1 0 182)" gradientunits="userSpaceOnUse" id="b" x1="33.834" x2="9.638" y1="161.999" y2="161.999">
#          <stop offset="0" stop-color="#FFE000">
#          </stop>
#          <stop offset=".409" stop-color="#FFBD00">
#          </stop>
#          <stop offset=".775" stop-color="orange">
#          </stop>
#          <stop offset="1" stop-color="#FF9C00">
#          </stop>
#         </lineargradient>
#         <path d="M27 24.3l-4.1-4.1v-.3l4.1-4.1.1.1 4.9 2.8c1.4.8 1.4 2.1 0 2.9l-5 2.7z" fill="url(#b)">
#         </path>
#         <lineargradient gradienttransform="matrix(1 0 0 -1 0 182)" gradientunits="userSpaceOnUse" id="c" x1="24.828" x2="2.07" y1="159.705" y2="136.947">
#          <stop offset="0" stop-color="#FF3A44">
#          </stop>
#          <stop offset="1" stop-color="#C31162">
#          </stop>
#         </lineargradient>
#         <path d="M27.1 24.2L22.9 20 10.4 32.5c.5.5 1.2.5 2.1.1l14.6-8.4" fill="url(#c)">
#         </path>
#         <lineargradient gradienttransform="matrix(1 0 0 -1 0 182)" gradientunits="userSpaceOnUse" id="d" x1="7.297" x2="17.46" y1="181.823" y2="171.661">
#          <stop offset="0" stop-color="#32A071">
#          </stop>
#          <stop offset=".069" stop-color="#2DA771">
#          </stop>
#          <stop offset=".476" stop-color="#15CF74">
#          </stop>
#          <stop offset=".801" stop-color="#06E775">
#          </stop>
#          <stop offset="1" stop-color="#00F076">
#          </stop>
#         </lineargradient>
#         <path d="M27.1 15.8L12.5 7.5c-.9-.5-1.6-.4-2.1.1L22.9 20l4.2-4.2z" fill="url(#d)">
#         </path>
#         <path d="M27 24.1l-14.5 8.2c-.8.5-1.5.4-2 0l-.1.1.1.1c.5.4 1.2.5 2 0L27 24.1z" opacity=".2">
#         </path>
#         <path d="M10.4 32.3c-.3-.3-.4-.8-.4-1.4v.1c0 .6.2 1.1.5 1.4v-.1h-.1zm21.6-11l-5 2.8.1.1 4.9-2.8c.7-.4 1-.9 1-1.4 0 .5-.4.9-1 1.3z" opacity=".12">
#         </path>
#         <path d="M12.5 7.6L32 18.7c.6.4 1 .8 1 1.3 0-.5-.3-1-1-1.4L12.5 7.5c-1.4-.8-2.5-.2-2.5 1.4V9c0-1.5 1.1-2.2 2.5-1.4z" fill="#FFF" opacity=".25">
#          <title>
#           hp-download-android-app
#          </title>
#         </path>
#        </svg>
#       </a>
#      </section>
#      <form action="/redirect/mobile" class="footer__platform-switch" method="post">
#       <input id="redirectMobile" name="after-signin-url" type="hidden" value="/car-search?postcode=G72%208JD&amp;year-to=2022&amp;include-delivery-option=on&amp;advertising-location=at_cars&amp;page=1"/>
#       <i class="icon icon-mobile">
#        <svg height="60" viewbox="0 0 36 60" width="36" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          View mobile website icon
#         </title>
#         <path d="M31.765 0H4.235C1.395 0 0 1.239 0 4v52c0 2.761 1.395 4 4.235 4h27.529C34.605 60 36 58.761 36 56V4c0-2.761-1.395-4-4.235-4zM21 57h-6c-1.169 0-2-.895-2-2s.831-2 2-2h6c1.169 0 2 .895 2 2s-.831 2-2 2zm12-6H3V3h30v48z">
#         </path>
#        </svg>
#       </i>
#       <button class="footer__nav-mobile tracking-footer-link" rel="nofollow" type="submit">
#        View mobile website
#       </button>
#      </form>
#      <section class="footer__nav-disclaimer">
#       <small>
#        <span>
#         Copyright © Auto Trader Limited 2022.
#        </span>
#        Auto Trader Limited is authorised and regulated by the Financial Conduct Authority in relation to consumer credit and insurance mediation activities. Our FCA firm reference number is 735711.
#        <strong>
#         Auto Trader Limited is a credit broker and not a lender.
#        </strong>
#        Representative finance examples are for illustrative purposes only. Finance is subject to status. Terms and conditions apply. Available to 18s and over. UK residents only. Auto Trader receives a fee from retailers advertising finance and may receive a commission from commercial partners for introducing customers to finance products. These fees and commissions do not influence the amount a customer pays.
#       </small>
#      </section>
#      <section class="footer__nav-disclaimer">
#       <span>
#        Registered office and headquarters
#       </span>
#       <address>
#        4th Floor
#        <br/>
#        1 Tony Wilson Place
#        <br/>
#        Manchester
#        <br/>
#        M15 4FN
#        <br/>
#        United Kingdom
#        <br/>
#        Registered number: 03909628
#       </address>
#      </section>
#     </nav>
#     <script>
#      const triggerFeedback = () => {
#         if(typeof document !== 'undefined' && !window) {
#             return null
#         } else if (window.usabilla_live !== undefined) {
#             window.usabilla_live('click')
#         } else {
#             let utagQueryParams = ''
#
#             if(window.utag !== undefined) {
#                 const pageName = '&page_name=' + window.utag.data['page_name']
#                 const loggedInStatus = '&logged_in_status=' + window.utag.data['logged_in_status']
#                 const platform = '&platform=' + window.utag.data['platform']
#                 const userId = '&userid=' + window.utag.data['userid']
#                 utagQueryParams =  utagQueryParams + pageName + loggedInStatus + platform + userId
#             }
#
#             const abTestGroupCookie = document.cookie.split('; ').filter((item) => item.split('=')[0] === 'abTestGroups')
#
#             const abTestGroups = (abTestGroupCookie.length > 0) ? '&ABTestAllocation=' + abTestGroupCookie[0].split('=')[1] : ''
#
#             const url = "http://survey.usabilla.com/live/s/61dc55f256b1187790030a31?url=" + encodeURIComponent(window.location.href) + utagQueryParams + abTestGroups
#             window.open(url, "_blank")
#         }
#     }
#     </script>
#    </div>
#   </footer>
#   <script type="text/javascript">
#    /*inline-script*/
#     var utag_data = {"platform":"desktop","page_name":"cars:search:known:results","page_name_granular":"desktop:cars:search:known:results-pg[1]","channel":"cars","section":"search","location_postcode":"g728jd","location_key":"dcfcce00f3112037","location_lat_long":"55.8167983212,-4.1688479017","vehicles_found":"404741","distance":"1501","search_criteria":"distance,max-age","max_age":"2022","keywords":"","sort_order":"relevance","page_number":"1","location_area":"glasgowsouth","loc_one":"g728","location_postcode_prefix":"g72","environment":"www","aoi":"PEU017,HYU117,FIA013,LEX018,MIN054,BMW057,SUB031,ISU026,FER005,CIT087,JAG089,VWA005","userid":"ID\u003dbe5f2dc7-72c7-4b2b-a2d5-ce3eb8bfac87","in_search_targeting":{"sr":[],"max_age":["2022"],"distance":["1501"],"used_new":["new","nearlynew","used"],"location_area":["glasgowsouth"],"loc_one":["g728"]}};
#
#     (function(dataLayer) {
#         var cookieValue = function(name) {
#             return (document.cookie.match('(^|[^a-zA-Z])%s=(.+?)(;|&|$)'.replace('%s', name)) || [])[2] || null;
#         };
#         dataLayer.urs_id = cookieValue('URS_DATABASE_ID');
#         dataLayer.logged_in_status = dataLayer.urs_id ? 'signed-in' : 'not-signed-in';
#         dataLayer.territory = (cookieValue('postcode') || '').toUpperCase().indexOf('BT') === 0 ? 'ni' : 'uk';
#         dataLayer.social_connection = cookieValue('PROVIDER');
#     })(utag_data);
#
#     (function(a,b,c,d){
#         var count = 0;
#         function loadJquery () {
#              var script = document.createElement('script');
#
#              script.src = "https://code.jquery.com/jquery-1.11.0.min.js";
#              script.crossorigin = "anonymous";
#              var head = document.getElementsByTagName('head')[0];
#              head.appendChild(script);
#          }
#
#         function loadAfterJQuery(one,two) {
#             if(typeof(jQuery) == 'undefined' && count < 20) {
#                 count++;
#                 setTimeout(function() {
#                     loadAfterJQuery(one,two);
#                 }, 300);
#             } else {
#                 a.parentNode.insertBefore(two,one);
#             }
#         }
#         a='//tags.tiqcdn.com/utag/autotrader/at-desktop/prod/utag.js';
#         b=document;c='script';
#         d=b.createElement(c);
#         d.src=a;
#         d.type='text/java'+c;
#         d.async=true;
#         var scriptElementsInHead=b.head.getElementsByTagName(c);
#         a=scriptElementsInHead[scriptElementsInHead.length-1];
#         if(!window.jQuery){
#             loadJquery();
#         }
#         loadAfterJQuery(a,d);
#     })();
#   </script>
#   <script>
#    if(window !== undefined && window.appVersion === undefined){
#             window.appVersion = '9690'
#         }
#         window.Promise || document.write('<script src="//cdn.jsdelivr.net/bluebird/3.5.0/bluebird.js"><\/script>')
#   </script>
#   <script async="" src="/static/9690/js/_generated/bundles/search-optimized.js">
#   </script>
#   <script async="" src="/static/9690/js/_generated/bundles/atds-header.js">
#   </script>
#   <div id="sp_message_container_687971" style="display: block;">
#    <iframe id="sp_message_iframe_687971" src="https://cmpv2.autotrader.co.uk/index.html?message_id=687971&amp;consentUUID=undefined&amp;preload_message=true&amp;hasCsp=true&amp;consent_origin=https%3A%2F%2Fcmpv2.autotrader.co.uk%2Fconsent%2Ftcfv2&amp;mms_origin=https%3A%2F%2Fcmpv2.autotrader.co.uk%2Fmms%2Fv2" title="SP Consent Message">
#    </iframe>
#   </div>
#   <iframe aria-hidden="true" id="lpSS_8925364891" name="lpSS_8925364891" role="presentation" src="https://tag.contactatonce.co.uk/le_secure_storage/storage.secure.min.html?loc=https%3A%2F%2Fwww.autotrader.co.uk&amp;providerId=245&amp;site=p-245&amp;env=uk&amp;tagDomain=tag.contactatonce.co.uk" style="width: 0px; height: 0px; position: absolute; top: -1000px; left: -1000px; display: none;" tabindex="-1" title="Intentionally blank">
#   </iframe>
#  </body>
# </html>

# %%
#Create Empty lists to hold the data
name = []
price = []
year = []
body = []
miles = []
engine_volume = []
engine_power =[]
transmission = []
fuel = []

#Scrapping Time

name_results  = soup.find_all('h3', class_='product-card-details__title')
for i in range(len(name_results)):
    name_stripped = name_results[i].text.strip()
    #print(name_results[i].text.strip())
    name.append(name_stripped)
price_results = soup.find_all('div', class_='product-card-pricing__price')
for i in range(len(price_results)):
    price_stripped = price_results[i].text.strip()
    #print(price[i].text.strip())
    price.append(price_stripped)
specs1 = soup.find_all('ul', attrs={'class': 'listing-key-specs'})
for i in specs1:
    spec_stripped = i.text.strip()
    spec_splitted = spec_stripped.split("\n")
    year.append(spec_splitted[0])
    body.append(spec_splitted[1])
    miles.append(spec_splitted[2])
    engine_volume.append(spec_splitted[3])
    engine_power.append(spec_splitted[4])
    transmission.append(spec_splitted[5])
    fuel.append(spec_splitted[6])
    print("-------")
    print(name)
    print(price)
    print(year)
    print(body)
    print(miles)
    print(engine_volume)
    print(engine_power)
    print(transmission)
    print(fuel)
    print("-------")
# Out:
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)']
# ['Hatchback']
# ['27,177 miles']
# ['1.5L']
# ['111PS']
# ['Manual']
# ['Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)']
# ['Hatchback', 'Estate']
# ['27,177 miles', '98,000 miles']
# ['1.5L', '2.0L']
# ['111PS', '217BHP']
# ['Manual', 'Manual']
# ['Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)']
# ['Hatchback', 'Estate', 'Saloon']
# ['27,177 miles', '98,000 miles', '153,000 miles']
# ['1.5L', '2.0L', '1.8L']
# ['111PS', '217BHP', '105BHP']
# ['Manual', 'Manual', 'Automatic']
# ['Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L']
# ['111PS', '217BHP', '105BHP', '136PS']
# ['Manual', 'Manual', 'Automatic', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)', '2002 (02 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe', 'Hatchback']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles', '92,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L', '1.6L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP', '90PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)', '2002 (02 reg)', '2011 (61 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe', 'Hatchback', 'Hatchback']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles', '92,000 miles', '76,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L', '1.6L', '1.6L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP', '90PS', '115PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)', '2002 (02 reg)', '2011 (61 reg)', '2009 (09 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe', 'Hatchback', 'Hatchback', 'Hatchback']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles', '92,000 miles', '76,000 miles', '117,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L', '1.6L', '1.6L', '2.5L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP', '90PS', '115PS', '255PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)', '2002 (02 reg)', '2011 (61 reg)', '2009 (09 reg)', '2008 (57 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe', 'Hatchback', 'Hatchback', 'Hatchback', 'Estate']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles', '92,000 miles', '76,000 miles', '117,000 miles', '173,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L', '1.6L', '1.6L', '2.5L', '2.0L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP', '90PS', '115PS', '255PS', '136PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)', '2002 (02 reg)', '2011 (61 reg)', '2009 (09 reg)', '2008 (57 reg)', '2007 (57 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe', 'Hatchback', 'Hatchback', 'Hatchback', 'Estate', 'MPV']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles', '92,000 miles', '76,000 miles', '117,000 miles', '173,000 miles', '138,000 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L', '1.6L', '1.6L', '2.5L', '2.0L', '1.8L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP', '90PS', '115PS', '255PS', '136PS', '140PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol']
# -------
# -------
# ['Toyota Yaris Hatchback', 'Audi A4 Avant', 'BMW 3 Series', 'BMW 1 Series', 'Vauxhall Corsa', 'Mazda MX-5', 'Saab 9-3', 'MINI Hatch', 'Vauxhall Astra', 'Subaru Impreza', 'Volvo V50', 'Vauxhall Zafira', 'Toyota Yaris Hatchback']
# ['£10,995', '£2,995', '£1,550', '£1,995', '£2,500', '£2,295', '£3,485', '£995', '£3,290', '£6,995', '£1,495', '£700', '£10,995']
# ['2017 (67 reg)', '2006 (06 reg)', '1988 (E reg)', '2012 (62 reg)', '2011 (11 reg)', '1998 (S reg)', '2002 (02 reg)', '2002 (02 reg)', '2011 (61 reg)', '2009 (09 reg)', '2008 (57 reg)', '2007 (57 reg)', '2017 (67 reg)']
# ['Hatchback', 'Estate', 'Saloon', 'Hatchback', 'Hatchback', 'Convertible', 'Coupe', 'Hatchback', 'Hatchback', 'Hatchback', 'Estate', 'MPV', 'Hatchback']
# ['27,177 miles', '98,000 miles', '153,000 miles', '77,000 miles', '68,000 miles', '210,000 miles', '70,124 miles', '92,000 miles', '76,000 miles', '117,000 miles', '173,000 miles', '138,000 miles', '27,177 miles']
# ['1.5L', '2.0L', '1.8L', '1.6L', '1.2L', '1.6L', '2.0L', '1.6L', '1.6L', '2.5L', '2.0L', '1.8L', '1.5L']
# ['111PS', '217BHP', '105BHP', '136PS', '85PS', '89BHP', '185BHP', '90PS', '115PS', '255PS', '136PS', '140PS', '111PS']
# ['Manual', 'Manual', 'Automatic', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual', 'Manual']
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol']
# -------

# %%
#Zipping our lists into a DataFrame
zipped =list(zip(name, price, year,body,miles,engine_volume,engine_power,transmission,fuel))


df = pd.DataFrame(zipped, columns=['model', 'price', 'year',"body","mileage","engine_volume","engine_power","transmission","fuel"])
df.head()
# Out:
#                     model    price           year       body        mileage  \
# 0  Toyota Yaris Hatchback  £10,995  2017 (67 reg)  Hatchback   27,177 miles
# 1           Audi A4 Avant   £2,995  2006 (06 reg)     Estate   98,000 miles
# 2            BMW 3 Series   £1,550   1988 (E reg)     Saloon  153,000 miles
# 3            BMW 1 Series   £1,995  2012 (62 reg)  Hatchback   77,000 miles
# 4          Vauxhall Corsa   £2,500  2011 (11 reg)  Hatchback   68,000 miles
#
#   engine_volume engine_power transmission    fuel
# 0          1.5L        111PS       Manual  Petrol
# 1          2.0L       217BHP       Manual  Petrol
# 2          1.8L       105BHP    Automatic  Petrol
# 3          1.6L        136PS       Manual  Petrol
# 4          1.2L         85PS       Manual  Petrol

# %%
#This is a Test Webdrive run, to see if it works. It does and should run a query on google search
#driver = webdriver.Chrome()  
#driver.maximize_window()  
#driver.delete_all_cookies() 
#driver.get("https://www.google.com/")  
#driver.find_element(By.ID,"W0wltc").click() 

#driver.find_element(By.NAME,"q").send_keys("javascript")

#driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]").click()

# %%
#Now a tricky part: Im trying to open that website and close a Cookie Pop-up, easier said than done
#Code doesnt "see" the pop-up at all, nothing helps,
#a bunch of commented code are my attempts to try different ways of closing the pop-up

#driver = webdriver.Chrome()  
#driver.maximize_window()  



#driver.get("https://www.autotrader.co.uk/car-search?postcode=G72%208JD&year-to=2022&include-delivery-option=on&advertising-location=at_cars&page=1")
#time.sleep(8)

    #I try to wait 20sec untill browser loads, but that doesnt help.

#print("Lets try")
#element = WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="notice"]/div[3]/div[2]/button[2]'))).click()


#print("Congrats you've closed the cookie pop-up!")

#I tried using partial text for "Accept", still doesnt work.
#I strongly suspect that it was done so hard by design in order to avoid people scraping data
#driver.find_element(By.PARTIAL_LINK_TEXT,'Accept').click()
#driver.implicitly_wait(6)

    #This next line is to click the "Next Page" button on the website, I hope it makes sense

#driver.find_element(By.XPATH,'/html/body/main/div[1]/section[2]/div/div/header/nav/ul/li[2]/a/i').click()
#driver.find_element(By.XPATH,'//*[@id="content"]/div/header/nav/ul/li[2]/a/i/svg/use').click()
#print("next page")

# %% [markdown]
# # Connect to Local Database

# %%
#Connection
protocol = 'postgresql'
username = 'postgres'
password = 'Engalub0'
host = 'localhost'
port = 5432
database_name = 'cars_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
#Check for the existing tables
engine.table_names()
# Out:
# ['csv_cars', 'scrapping_cars']

# %% [markdown]
# ## Load the DataFrames into the Database

# %%
#CSV dataframe
new_cars_df.to_sql(name='csv_cars', con=engine, if_exists='append', index=False)

# %%
#Json dataframe
df.to_sql(name='scrapping_cars', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added

# %%
pd.read_sql_query('select * from csv_cars', con=engine).head()
# Out:
#      price    year manufacturer                     model   mileage fuel  \
# 0  33590.0  2014.0          gmc  sierra 1500 crew cab slt   57923.0  gas
# 1  22590.0  2010.0    chevrolet            silverado 1500   71229.0  gas
# 2  39590.0  2020.0    chevrolet       silverado 1500 crew   19160.0  gas
# 3  30990.0  2017.0       toyota      tundra double cab sr   41124.0  gas
# 4  15000.0  2013.0         ford                 f-150 xlt  128000.0  gas
#
#   transmission
# 0        other
# 1        other
# 2        other
# 3        other
# 4    automatic

# %%
pd.read_sql_query('select * from scrapping_cars', con=engine).head()
# Out:
#             model   price           year       body        mileage  \
# 0    Nissan Micra  £9,995  2018 (18 reg)  Hatchback   16,663 miles
# 1   Audi A4 Avant  £2,995  2006 (06 reg)     Estate   98,000 miles
# 2    BMW 3 Series  £1,550   1988 (E reg)     Saloon  153,000 miles
# 3    BMW 1 Series  £1,995  2012 (62 reg)  Hatchback   77,000 miles
# 4  Vauxhall Corsa  £2,500  2011 (11 reg)  Hatchback   68,000 miles
#
#   engine_volume engine_power transmission    fuel
# 0          1.0L         71PS       Manual  Petrol
# 1          2.0L       217BHP       Manual  Petrol
# 2          1.8L       105BHP    Automatic  Petrol
# 3          1.6L        136PS       Manual  Petrol
# 4          1.2L         85PS       Manual  Petrol
